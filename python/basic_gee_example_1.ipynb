# %%
####### XXX

# Step 1: Sign up for a Google Earth Engine Account here:
# https://earthengine.google.com/signup/

# you will use this to authenticate your account with GEE to run the script and
# utilize GEE layers

# %%
# get any missing modules
! pip install earthengine-api geemap
# Out:
# Requirement already satisfied: earthengine-api in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (0.1.273)
# Requirement already satisfied: geemap in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (0.8.18)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (0.1.0)
# Requirement already satisfied: google-auth>=1.4.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (1.32.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (0.19.1)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (1.12.8)
# Requirement already satisfied: future in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (0.18.2)
# Requirement already satisfied: httplib2shim in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (0.0.3)
# Requirement already satisfied: google-cloud-storage in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (1.19.0)
# Requirement already satisfied: six in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from earthengine-api) (1.16.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (1.30.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (3.0.1)
# Requirement already satisfied: packaging>=14.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (21.0)
# Requirement already satisfied: pytz in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.1)
# Requirement already satisfied: protobuf>=3.12.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (3.17.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.25.1)
# Requirement already satisfied: setuptools>=40.3.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (49.6.0.post20210108)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.53.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (4.7.2)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.10)
# Requirement already satisfied: whiteboxgui in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.3.0)
# Requirement already satisfied: folium>=0.11.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.12.1)
# Requirement already satisfied: python-box in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (5.3.0)
# Requirement already satisfied: pycrs in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (1.0.2)
# Requirement already satisfied: sankee in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.0.5)
# Requirement already satisfied: pyshp>=2.1.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (2.1.3)
# Requirement already satisfied: ipyleaflet>=0.14.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.14.0)
# Requirement already satisfied: ipyevents in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.8.2)
# Requirement already satisfied: click in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (8.0.1)
# Requirement already satisfied: pandas in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (1.3.0)
# Requirement already satisfied: colour in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: bqplot in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.12.29)
# Requirement already satisfied: matplotlib in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (3.4.2)
# Requirement already satisfied: ffmpeg-python in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: geeadd>=0.5.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.5.5)
# Requirement already satisfied: geojson in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (2.5.0)
# Requirement already satisfied: ipynb-py-convert in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.4.6)
# Requirement already satisfied: googledrivedownloader in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.4)
# Requirement already satisfied: ipytree in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.2.1)
# Requirement already satisfied: ipyfilechooser in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.4.4)
# Requirement already satisfied: geocoder in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: pillow in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (8.3.1)
# Requirement already satisfied: mss in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (6.1.0)
# Requirement already satisfied: numpy in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (1.21.0)
# Requirement already satisfied: voila in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geemap) (0.2.10)
# Requirement already satisfied: jinja2>=2.9 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from folium>=0.11.0->geemap) (3.0.1)
# Requirement already satisfied: branca>=0.3.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from folium>=0.11.0->geemap) (0.4.2)
# Requirement already satisfied: logzero>=1.5.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geeadd>=0.5.1->geemap) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.2.1)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipyleaflet>=0.14.0->geemap) (7.6.3)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipyleaflet>=0.14.0->geemap) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (6.0.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (7.25.0)
# Requirement already satisfied: jupyter-client in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0appnope,>=0.1.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.3.0)
# Requirement already satisfied: tornado>=4.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (6.1)
# Requirement already satisfied: decorator in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (5.0.9)
# Requirement already satisfied: pickleshare in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (4.8.0)
# Requirement already satisfied: appnope in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (3.0.19)
# Requirement already satisfied: backcall in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.2.0)
# Requirement already satisfied: pygments in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (2.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: jupyter-core in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (6.4.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.7.1)
# Requirement already satisfied: prometheus-client in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.10.1)
# Requirement already satisfied: nbconvert in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (6.1.0)
# Requirement already satisfied: pyzmq>=17 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (22.1.0)
# Requirement already satisfied: argon2-cffi in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.14.6)
# Requirement already satisfied: pycparser in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (2.20)
# Requirement already satisfied: ratelim in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-resumable-media>=0.3.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api) (1.3.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api) (1.7.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from google-resumable-media>=0.3.1->google-cloud-storage->earthengine-api) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.4.3)
# Requirement already satisfied: bleach in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.3)
# Requirement already satisfied: defusedxml in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.1.2)
# Requirement already satisfied: testpath in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.5.3)
# Requirement already satisfied: async-generator in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (1.5.1)
# Requirement already satisfied: webencodings in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.14.0->geemap) (0.5.1)
# Requirement already satisfied: plotly in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from sankee->geemap) (5.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from plotly->sankee->geemap) (8.0.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from voila->geemap) (1.9.0)
# Requirement already satisfied: websocket-client in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (3.2.1)
# Requirement already satisfied: requests-unixsocket in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (0.2.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.2.0)
# Requirement already satisfied: whitebox in /Users/sserbin/miniconda3/envs/ee/lib/python3.9/site-packages (from whiteboxgui->geemap) (1.5.1)

# %%
# setup modules
import numpy as np
#import matplotlib.pyplot as pl
#import matplotlib as mpl
#import pandas as pd
import sys,os,os.path,tempfile

# spatial modules
try:
    import google.colab
    import geemap.foliumap as geemap # use folium instead so coloramps work on goolge collab
    # https://geemap.org/notebooks/geemap_and_folium/
except:
#    import geemap as geemap
    import geemap.foliumap as geemap
    
import ee
import geemap.colormaps as cm

import warnings
warnings.filterwarnings('ignore') #don't display warnings

# %%
## setup output. defined dir or system temp dir
data_dir=os.path.expanduser(os.path.join(tempfile.gettempdir(),'gee_output'))

if not os.path.exists(data_dir):
    os.makedirs(data_dir)

print(" ")
print("****** GEE and script output folder ******")
print("****** Note: In Google Collab, use the dir navigation tool on the left of the screen ******")
print("****** Use the dir navigation to go up one level, then navigate to tmp/gee_output ******")
print(data_dir)
# Out:
#
# ****** GEE and script output folder ******
# ****** Note: In Google Collab, use the dir navigation tool on the left of the screen ******
# ****** Use the dir navigation to go up one level, then navigate to tmp/gee_output ******
# /var/folders/xp/h3k9vf3n2jx181ts786_yjrn9c2gjq/T/gee_output

# %%
##### initialize ee API  - you need to authenticate with GEE and initialize

## Trigger the initialization flow. You only need to do this once while running notebook
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ## After inserting the API key initialize GEE
    ee.Initialize()

# %%
##### Get GEE datasets

### TIGER roads
roads = ee.FeatureCollection('TIGER/2016/Roads');

### Get Landsat 8 data - select scenes from a specific date range over Long Island
li_roi = ee.Geometry.Rectangle(-71.108102, 40.603476, -74.165714, 41.204794);

l8 = ee.ImageCollection('LANDSAT/LC08/C01/T1_8DAY_NDVI').filterDate('2018-07-01', '2018-09-10')\
.filterBounds(li_roi);
l8_ndvi = l8.select('NDVI');

# Maximum Value Composite
# https://developers.google.com/earth-engine/guides/ic_composite_mosaic
l8_maxval_ndvi_composite = l8_ndvi.max();

# %%
#### Map Landsat 8 Maximum Value Composite with RGB UAS image
ndvi_palette = cm.get_palette('viridis', n_class=30)
ndviViz = {'min': 0.0, 'max': 1.0, 'palette': ndvi_palette, 'opacity': 1}

Map = geemap.Map(center=[40.816015,-73.035151], zoom=8)
Map.add_basemap('ROADMAP') # Add Google Map
Map.addLayer(l8_maxval_ndvi_composite, ndviViz, 'Landsat 8 NDVI');
Map.add_colorbar(colors=ndviViz['palette'], vmin=ndviViz['min'], 
                     vmax=ndviViz['max'],
                     caption = "Landsat 8 NDVI (-)",
                     layer_name="Landsat 8 NDVI", 
                     position="bottomright")
#Map.addLayer(roads, {}, 'Census roads');
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f651cf0195004291857d1462cebe90b4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f651cf0195004291857d1462cebe90b4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20% ...
